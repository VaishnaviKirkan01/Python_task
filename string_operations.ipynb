# %%
name ="vaishnavi navnath kirkan"
last= "kirkan"
age="22"
address="Maharashtra"

info = name +" "+last+age+address
info
# Out:
# 'vaishnavi navnath kirkan kirkan22Maharashtra'

# %%
info=f" her name is {name} {last} and age is = {age} "
info
# Out:
# ' her name is vaishnavi navnath kirkan kirkan and age is = 22 '

# %%
name [7]
# Out:
# 'v'

# %%
name[2:7]
# Out:
# 'ishna'

# %%
last[0:8]
# Out:
# 'kirkan'

# %%
name[4:]
# Out:
# 'hnavi navnath kirkan'

# %%
name[-7]
# Out:
# ' '

# %%
name[78]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 name[78]
#
# IndexError: string index out of range

# %%
recipe= '''
asdfhjkjgxklytrsdfjiuytresdf
sdyuijgfdghjjgfddkhgf
sdfghhbvcxserugfdsrt
6ugfdetujhcxzaeryumjh jo j
ZWEVIPL[QAQGHUOKPL;SSN,
'''
recipe
# Out:
# '\nasdfhjkjgxklytrsdfjiuytresdf\nsdyuijgfdghjjgfddkhgf\nsdfghhbvcxserugfdsrt\n6ugfdetujhcxzaeryumjh jo j\nZWEVIPL[QAQGHUOKPL;SSN,\n'

# %%
print(recipe)
# Out:
# asdfhjkjgxklytrsdfjiuytresdf
# sdyuijgfdghjjgfddkhgf
# sdfghhbvcxserugfdsrt
# 6ugfdetujhcxzaeryumjh jo j
# ZWEVIPL[QAQGHUOKPL;SSN,

# %%
gh="["
gh in recipe
# Out:
# True

# %%
'milk' in recipe
# Out:
# False

# %%
file=" dvitiya.pdf"
file.endswith(".pdf")
# Out:
# True

# %%
vegetable="gobi, allu, bhindi "
fruits="plum, litchi, apple, "

info= f" i ate {vegetable} vegetables and {fruits} these fruits today"
info
# Out:
# ' i ate gobi, allu, bhindi  vegetables and plum, litchi, apple,  these fruits today'

# %%
st=" the himalayas are one of the youngest mountain ranges in the planet"
st
# Out:
# ' the himalayas are one of the youngest mountain ranges in the planet'

# %%
st[0:14]
# Out:
# ' the himalayas'

# %%
st[-30:-15]
# Out:
# ' mountain range'

# %%
print(f" {string[0:14]} {string[-13:]}")
# Out:
#  there are 9 pl  solar system

# %%
string="there are 9 planets in the solar system"
string
# Out:
# 'there are 9 planets in the solar system'

# %%
string= string.replace('9','8') 
string
# Out:
# 'there are 8 planets in the solar system'
