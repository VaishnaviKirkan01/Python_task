# %% [markdown]
# 30 Questions on Class, Object, Private Attributes, Getter, Setter & Class
# Attributes

# %%
# 1. Create a class Student with instance attributes name and age. Create two objects
# and print their details.
class Student:
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def display(self):
        print("Name is",self.name)
        print("Age is ",self.age)

S1=Student("binod",45)
S2=Student("arya",56)
S1.display()
print()
S2.display()
# Out:
# Name is binod
# Age is  45
#
# Name is arya
# Age is  56

# %%
# 2. Define class Car with attributes brand, model, and year. Create an object and
# display all attributes.
class Car:
    def __init__(self,brand,model,year):
        self.brand=brand
        self.model=model
        self.year=year
    def display(self):
        print(f"Brand= {self.brand} \nModel = {self.model} \nYear = {self.year}")
c1=Car("BMW","cg123",2026)
c1.display()
# Out:
# Brand= BMW
# Model = cg123
# Year = 2026

# %%
# 3. Create class Book with attributes title, author, price. Add a method display_info().
class Book:
    def __init__(self,title,author,price):
        self.title=title
        self.author=author
        self.price=price
    def display_info(self):
        print(f"Title= {self.title} \nAuthor = {self.author} \nPrice = {self.price}")
b1=Book("the silent patient","rina kent",2000)
b1.display_info()
# Out:
# Title= the silent patient
# Author = rina kent
# Price = 2000

# %%
# 4. Create class Employee with attributes emp_id, name, salary. Create 3 objects.
class Employee:
    def __init__(self,emp_id,name,salary):
        self.emp_id=emp_id
        self.name=name
        self.salary=salary
    def display(self):
        print(f" employee id={self.emp_id} \n name ={self.name} \n salary={self.salary}")

Emp1=Employee(123,"manoj",200000)
Emp1.display()
Emp2=Employee(124,"joti",300000)
Emp2.display()
Emp3=Employee(125,"arjun",1200000)
Emp3.display()
# Out:
#  employee id=123
#  name =manoj
#  salary=200000
#  employee id=124
#  name =joti
#  salary=300000
#  employee id=125
#  name =arjun
#  salary=1200000

# %%
# 5. Write a class Mobile with attributes brand, price, color. Print object using __str__method.
class Mobile:
    def __init__(self,brand,price,color):
        self.brand=brand
        self.price=price
        self.color=color
    def __str__(self):
        print(f"Brand = {self.brand} \nPrice = {self.price} \ncolor = {self.color}")

M=Mobile("poco",200000,"pink")
M.__str__()
# Out:
# Brand = poco
# Price = 200000
# color = pink

# %%
# 6. Create class Rectangle with attributes length and width. Add method to calculate area.
class Rectangle:
    def __init__(self,length,width):
        self.length=length
        self.width=width
    def area(self):
        print(f"Area of rectangle is {self.length+self.width}")

R=Rectangle(23,45)
R.area()
# Out:
# Area of rectangle is 68

# %%
# 7. Define class Person with attributes name and city. Create object and change city
# value.
class Person:
    def __init__(self,name,city):
        self.name=name
        self.city=city
    def display(self):
        print(f"Name= {self.name} \nCity= {self.city}")

    def change(self,new):
        self.city=new
        print(f"Chnaged name = {self.city}")        

P=Person("neha","hyderabad")
P.display()
P.change("namded")
# Out:
# Name= neha
# City= hyderabad
# Chnaged name = namded

# %%
# 8. Create class Laptop and show how to create multiple objects with different values.
class Laptop:
    def __init__(self,Brand):
        self.brand=Brand
    def display(self):
        print(f"The laptop brand is {self.brand}")

L1=Laptop("MSI")
L1.display()
L2=Laptop("asus")
L2.display()
# Out:
# The laptop brand is MSI
# The laptop brand is asus

# %%
# Class Attributes (9-15)
# 9. Create class Student with class attribute school_name = "City School". Print it
# using class name and object.
class Student:
    school_name="City School"
    def display(self):
        print(f"The school name is= {Student.school_name}")

s=Student()
s.display()
# Out:
# The school name is= City School

# %%
# 10. Create class Bank with class attribute bank_name. Change its value using class
# name and check effect on objects.
class Bank:
    bank_name="state bank of india"
    def display(self):
        print(f"Bank name= {Bank.bank_name}")
    def change(self,new):
        Bank.bank_name=new
        print(f"updated bank= {Bank.bank_name}")
        

bank=Bank()
bank.display()
bank.change("ICICI")
# Out:
# Bank name= state bank of india
# updated bank= ICICI

# %%
# 11. Define class Counter with class attribute count = 0. Add method to increment
# count.
class Counter:
    count=0
    def set_count(self,count):
        count+=1
        print(f"the incremented counter= {count}")
    

C=Counter()
C.set_count(0)
# Out:
# the incremented counter= 1

# %%
# 12. Create class Employee with class attribute company = "ABC Corp". Show that all
# objects share it.
class Employee:
    company="ABC Corp"
    def __init__(self,name,id_):
        self.name=name
        self.id_=id_
    def display(self):
        print("Name = ",self.name)
        print("Id = ",self.id_)
        print("company = ",Employee.company)

Emp1=Employee("vishal",34)
Emp1.display()
print()
Emp2=Employee("sam",34)
Emp2.display()
# Out:
# Name =  vishal
# Id =  34
# company =  ABC Corp
#
# Name =  sam
# Id =  34
# company =  ABC Corp

# %%
# 13. In class Circle, add class attribute pi = 3.14. Use it in area calculation method.
class Circle:
    pi=3.14

    def __init__(self,r):
        self.radius=r
    def area(self):
        a=2*Circle.pi*self.radius*self.radius
        print(f"Area= {a}")

C=Circle(3)
C.area()
# Out:
# Area= 56.519999999999996

# %%
# 14. Create class MathUtils with class attribute version = "1.0". Print it.
class MathUtils:
    version = "1.0"
    def display(self):
        print(f"The version is {MathUtils.version}")

M=MathUtils()
M.display()
# Out:
# The version is 1.0

# %%
# 15. Show difference between class attribute and instance attribute with example of
# class Player.
class Player:
    Game="football"
    def __init__(self,name):
        self.name=name
    def display(self):
        print("player name",self.name)
        print("Game= " ,Player.Game)

Pl=Player("messi")
Pl.display()
print()
PL1=Player("neymar")
PL1.display()
# Out:
# player name messi
# Game=  football
#
# player name neymar
# Game=  football

# %%
# Private Attributes (16-22)
# 16. Create class BankAccount with private attribute __balance. Try to access it
# directly (show error).
class BankAccount:
    def __init__(self,a_b):
        self.__balance=a_b
    def display(self):
        print("Bank balance is ",self.__balance)

ba=BankAccount(20000)
ba.display()
ba.self.__balance
# Out:
# Bank balance is  20000
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[86], line 12
#      10 ba=BankAccount(20000)
#      11 ba.display()
# ---> 12 ba.self.__balance
#
# AttributeError: 'BankAccount' object has no attribute 'self'

# %%
# 17. Define class Student with private attribute __marks. Print it using name
# mangling.
class Student:
    def __init__(self,marks):
        self.__marks=marks
    def display(self):
        print(self._Student__marks)
Std=Student(79)
Std.display()
# Out:
# 79

# %%
# 18. Create class Employee with private __salary. Show how it becomes
# _ClassName__salary.
class Employee:
    def __init__(self,salary):
        self.__salary=salary
    def display(self):
        print(self._Employee__salary)
Emp=Employee(20000)
Emp.display()
# Out:
# 20000

# %%
# 19. In class Product, make __price private. Try accessing from outside.
class Product:
    def __init__(self,price):
        self.__price=price
    def display(self):
        print(f"Price = {self.__price}")

pr=Product(2000)
pr.display()
pr.self.__price
# Out:
# Price = 2000
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[146], line 10
#       8 pr=Product(2000)
#       9 pr.display()
# ---> 10 pr.self.__price
#
# AttributeError: 'Product' object has no attribute 'self'

# %%
# 20. Create class User with private __password. Demonstrate name mangling.
class User:
    def __init__(self,password):
        self.__password=password
    def display(self):
        print(self._User__password)

U=User(1234)
U.display()
# Out:
# 1234

# %%
# 21. Define class Car with private attributes __model and __year.
class Car:
    def __init__(self,model,year):
        self.__model=model
        self.__year=year
    def get_display(self):
        print(self.__model)
        print(self.__year)

c=Car("16 gen",2023)
c.get_display()
# Out:
# 16 gen
# 2023

# %%
# 22. Create class Account with private __account_number.
class Acount:
    def __init__(self,account_number):
        self.__account_number=account_number
    def get_acc(self):
        print("acount number is ",self.__account_number)

A=Acount(12345)
A.get_acc()
# Out:
# acount number is  12345

# %%
# Getter and Setter (23-30)
# 23. Create class Student with private __marks. Add getter and setter methods.
class Student:
    def __init__(self,marks):
        self.__marks=marks
    def get_marks(self):
        return self.__marks
    def set_marks(self,new):
        self.__marks+=new
        print("the updated marks are",self.__marks)

std=Student(23)
std.get_marks()
std.set_marks(6)
# Out:
# the updated marks are 29

# %%
# 24. In class BankAccount, add getter and setter for private __balance with validation.
class BankAccount:
    def __init__(self,bal):
        self.__balance=bal
    def get_bal(self):
        return self.__balance
    def set_bal(self):
        print("the balance is ",self.__balance)

ba=BankAccount(120000)
ba.get_bal()
ba.set_bal()
# Out:
# the balance is  120000

# %%
# 25. Create class Employee with private __salary. Setter should not allow value below5000.
class Employee:
    def __init__(self,salary):
        self.__salary=salary
    def get_sal(self):
        return self.__salary
    def set_sal(self,value):
        if value>=5000:
            print("INVALID")
        else:
            self.__salary+=value
            print(self.__salary)

emp=Employee(200)
emp.get_sal()
emp.set_sal(34)
# Out:
# 234

# %%
# 26. Define class Temperature with private __celsius. Add getter and setter with
# conversion.
class Temperature:
    def __init__(self,celsius):
        self.__celsius=celsius
    def get_temp(self):
        return self.__celsius
    def set_temp(self,conv):

# %%
# 27. Create class Person with private __age. Add setter with validation (age between0-120).
class Person:
    def __init__(self,age):
        self.__age=age
    def get_age(self):
        return self.__age
    def set_age(self,age):
        if age<=0 and age<=120:
            print(self.__age)
        else:
            print("INVALID AGE")

per=Person(23)
per.get_age()
per.set_age(12)
# Out:
# 23

# %%
# 28. In class Product, add getter and setter for private __price with discount logic.
class Product:
    def __init__(self,price):
        self.__price=price
    def get_price(self):
        return self.__price
    def set_price(self,amount):
        if amount>=5000:
            self.__price=amount*0.20
        elif amount>=2000 and amount <5000:
            self.__price=amount*0.10
        elif amount>=1000 and amount <2000:
            self.__price=amount*0.05
        else:
            print("NO DISCOUNT")


pr=Product(1300)
pr.get_price()
pr.set_price(18000)
print("price after discount",pr.get_price())
# Out:
# price after discount 3600.0

# %%
# 29. Create class Mobile with private __price. Add setter that prints message on price change.
class Mobile:
    def __init__(self,price):
        self.__price=price
    def get_price(self):
        return self.__price
    def set_price(self,new_price):
        self.__price=new_price
        print("The new phone price is ",new_price)

Mo=Mobile(20000)
Mo.get_price()
Mo.set_price(100000)
# Out:
# The new phone price is  100000

# %%
# 30. Define class Rectangle with private __length and __width. Add getter/setter and
# area method.
class Rectangle:
    def __init__(self,length,width):
        self.__length=length
        self.__width=width
    def get_A(self,area):
        return area
    def set_A(self,area):
        
        area=self.__length+self.__width
        print("Area= ",area)

rect=Rectangle(23,45)
rect.get_A(0)
rect.set_A(0)
# Out:
# Area=  68

# %%
# Hard Questions on OOP (with extra conditions in Update / Setter methods)
# 1. (Hard) Create class Employee with private attribute __salary. Add getter and
# setter with these conditions in setter:
# • Salary cannot be less than 5000.
# • Salary cannot be increased by more than 20% at once.
#     • Keep track of last updated salary using class attribute. Add class method
# get_total_employees().

class Employee:
    total_employees = 0
    last_updated_salary = 0

    def __init__(self, salary):
        self.__salary = salary
        Employee.total_employees += 1

    def get_salary(self):
        return self.__salary

    def set_salary(self, new_salary):
        if new_salary < 5000:
            print("Invalid Salary")
        elif new_salary > self.__salary * 1.2:
            print("Increase cannot exceed 20%")
        else:
            self.__salary = new_salary
            Employee.last_updated_salary = new_salary

    @classmethod
    def get_total_employees(cls):
        return cls.total_employees



e = Employee(10000)
e.set_salary(11000)
print(e.get_salary())
print(Employee.last_updated_salary)
print(Employee.get_total_employees())
# Out:
# 11000
# 11000
# 1

# %%
# 2. (Hard) Create class BankAccount with private __balance. Implement setter for
# balance with these rules:
# • Balance cannot go below minimum balance (1000).
# • If balance > 100000, give 5% bonus automatically.
# • Log every update (use a class list to store history). Add getter and class
# method to show total accounts created.
class BankAccount:
    total_acc=2
    def __init__(self,balance):
        self.__balance=balance

    def get(self):
        return self.__balance
    def set(self):
        if self.__balance<1000:
            print("INVALID !! MINIMUM BALANCE")
            if self.__balance>100000:
                self.__balance+=5/self.__balance
                print("BONUS IS",self.__balance)
            else:
                print(self.__balance)

        else:
            print(self.__balance)

    @classmethod
    def get_count(cls):
        return cls.total_acc


b=BankAccount(123445678)
b.get()
b.set()
b.get_count()
# Out:
# 123445678
# 2

# %%
# 3. (Hard) Create class Student with private __marks (list of 5 subjects). Add setter
# for marks with conditions:
# • Each mark must be between 0 and 100.
# • Average cannot decrease from previous average.
# • If any mark < 40, automatically set status to "Failed". Add getter and class
# attribute total_students.
class Student:
    total_students=1
    def __init__(self,marks):
        self.__marks=marks
    def get_marks(self):
        return self.__marks
    def set_marks(self,avg):
        if any(m < 0 or m > 100 for m in self.__marks):
            return "Invalid marks"
            avg=sum(self.__marks)/5

            if self.__marks<40:
                return "Failed"
            else:
                return self.__marks

    @classmethod
    def get_total_std(cls):
        return cls.total_students


std=Student(23)
std.get_marks()
std.set_marks(35)
std.get_total_std()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[263], line 30
#      28 std=Student(23)
#      29 std.get_marks()
# ---> 30 std.set_marks(35)
#      31 std.get_total_std()
#
# Cell In[263], line 14, in Student.set_marks(self, avg)
#      13 def set_marks(self,avg):
# ---> 14     if any(m < 0 or m > 100 for m in self.__marks):
#      15         return "Invalid marks"
#      16         avg=sum(self.__marks)/5
#
# TypeError: 'int' object is not iterable

# %%
# 4. (Hard) Create class Product with private __price and __discount. In setter for
# price:
# • New price cannot be lower than 80% of original price.
# • If price > 5000, discount automatically becomes 15%.
# • Update a class attribute total_revenue on every price change. Add proper
# getter and setter.

class Product:
    total_revenue=0
    def __init__(self,price,discount):
        self.__price=price
        self.__discount=discount
    def get_pr(self):
        return self.__price
    def set_pr(self,new):
        if new>= 80/self.__price:
            if self.__price>5000:
                new=15/self.__price
            else:
                print(new)

        else:
            print("INVALID")
    def get_total_revenue(cls):
        return cls.total_revenue
    def set_total_revenue(cls,new):
        cls.total_revenue+=1
        print(cls.total_revenue)

p=Product(2300,10)
p.get_pr()
p.set_pr(200)
p.get_total_revenue()
p.set_total_revenue(1)
# Out:
# 200
# 1

# %%
# 5. (Hard) Create class User with private __password and __age. In setter methods:
# • Password must be at least 8 characters and contain at least 1 digit.
# • Age cannot be decreased (once set).
# • If age >= 60, automatically set senior_citizen = True (class attribute tracking).
# Add update method that updates both with validation.

class User:
    senior_citizen = True
    def __init__(self,passw,age):
        self.__password=passw
        self.__age=age
    def get_user(self):
        return self.__password
    def set_user(self):
        if  self.__password==8 and self.__password==isdigit():
            print(self.__password)
        else:
            print("ENTER ATLEAST CHAR")
