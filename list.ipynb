# %%
item=['cheese','popcorn','icecream']
item
# Out:
# ['cheese', 'popcorn', 'icecream']

# %%
item[2]
# Out:
# 'icecream'

# %%
item[:2]
# Out:
# ['cheese', 'popcorn']

# %%
item.append('cake')
item
# Out:
# ['cheese', 'popcorn', 'icecream', 'cake']

# %%
item.append('choclate')
item
# Out:
# ['cheese', 'popcorn', 'icecream', 'cake', 'choclate', 'choclate']

# %%
item.remove('cheese')
item
# Out:
# ['popcorn', 'icecream', 'cake', 'choclate', 'choclate']

# %%
item.insert(0,'butter')
item
# Out:
# ['butter',
#  'butter',
#  'butter',
#  'popcorn',
#  'butter',
#  'butter',
#  'icecream',
#  'cake',
#  'choclate',
#  'choclate']

# %%
item[1]='fruit'

# %%
item
# Out:
# ['butter',
#  'fruit',
#  'butter',
#  'popcorn',
#  'butter',
#  'butter',
#  'icecream',
#  'cake',
#  'choclate',
#  'choclate']

# %%
'rice' in item
# Out:
# False

# %%
item.sort()
item
# Out:
# ['butter',
#  'butter',
#  'butter',
#  'butter',
#  'cake',
#  'choclate',
#  'choclate',
#  'fruit',
#  'icecream',
#  'popcorn']

# %%
len(item)
# Out:
# 10
